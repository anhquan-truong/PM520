# %% [markdown]
# <a href="https://colab.research.google.com/github/anhquan-truong/PM520/blob/main/Lab_11_MCMC_BlackJAX_AnhQuanTRUONG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Planet Rock, or: Introduction to Markov Chain Monte Carlo (MCMC)
#
# This is different from variational inference, which we have a simpler distribution to approximate the true distribution. Here we we don't have this simpler distribution
#
# [Markov Chain Monte Carlo (MCMC)](https://en.wikipedia.org/wiki/Markov_chain_Monte_Carlo) is a family of algorithms for sampling from complex probability distributions, especially when direct sampling is infeasible. It is widely used in Bayesian statistics, statistical physics, and machine learning.
#
# ## The Target Distribution
#
# Assume we want to sample from a target distribution $\pi(x)$ over a state space $\mathcal{X}$. Often, the target is known only up to a normalizing constant:
# $$
# \pi(x) = \frac{f(x)}{Z}, \quad \text{where} \quad Z = \int_{\mathcal{X}} f(x) \, dx.
# $$
# Direct sampling is difficult when $Z$ is unknown or when $f(x)$ is complex, and MCMC provides a workaround.
#
# ## Markov Chain Fundamentals
#
# A [Markov chain](https://en.wikipedia.org/wiki/Markov_chain) is a sequence of random variables $\{x^{(t)}\}_{t=0}^\infty$ with the property that the future state depends only on the current state:
# $$
# P(x^{(t+1)} \mid x^{(t)}, x^{(t-1)}, \dots, x^{(0)}) = P(x^{(t+1)} \mid x^{(t)}).
# $$
#
# The transition probability from state $x$ to $x'$ is denoted as:
# $$
# T(x' \mid x) = P(x^{(t+1)} = x' \mid x^{(t)} = x).
# $$
#
# The chain has a **stationary distribution** $\pi(x)$ if it satisfies:
# $$
# \pi(x') = \int_{\mathcal{X}} \pi(x) \, T(x' \mid x) \, dx.
# $$
#
# ## The Metropolis-Hastings Algorithm
#
# One of the most popular MCMC algorithms is the [Metropolis-Hastings algorithm](https://en.wikipedia.org/wiki/Metropolis%E2%80%93Hastings_algorithm). It works by constructing a Markov chain whose stationary distribution is the target $\pi(x)$.
#
#
#
# ### Proposal Mechanism
#
# The algorithm uses a **proposal distribution** $q(x' \mid x)$ to generate a candidate state $x'$ from the current state $x$.
#
# ### Acceptance Probability
# [Nicholas Metropolis](https://en.wikipedia.org/wiki/Nicholas_Metropolis) and co-authors proposed the following acceptance rule:
# The candidate $x'$ is accepted with probability,
#   $$
#   \alpha(x, x') = \min\left(1, \frac{\pi(x')}{\pi(x)}\right).
#   $$
# [W.K. Hastings](https://en.wikipedia.org/wiki/W._K._Hastings) generalized this rule as,
# $$
# \alpha(x, x') = \min\left(1, \frac{\pi(x') \, q(x \mid x')}{\pi(x) \, q(x' \mid x)}\right).
# $$
# Note that if $q$ is symmetric (i.e. $q(x' \mid x) = q(x \mid x'))$ then the Hastings rule is equivalent to the Metropolis rule.
#
# ### Algorithm Steps
#
# 1. **Initialization**: Choose an initial state $x^{(0)}$.
# 2. **Iteration**: For $t = 0, 1, \ldots, N-1$:
#    - **Propose**: Sample a candidate $x' \sim q(x' \mid x^{(t)})$.
#    - **Compute Acceptance**: Calculate the acceptance probability $\alpha(x^{(t)}, x')$.
#    - **Accept or Reject**:
#      - With probability $\alpha(x^{(t)}, x')$, set $x^{(t+1)} = x'$.
#      - Otherwise, set $x^{(t+1)} = x^{(t)}$.
#
# The samples $\{x^{(t)}\}$ produced by this process converge to the target distribution $\pi(x)$ under certain regularity conditions.
#
# ## Convergence and Burn-in
#
# To ensure that the Markov chain has reached its stationary distribution, it is common to discard an initial set of samples known as the **burn-in period**:
# $$
# \text{Burn-in: } \{x^{(1)}, x^{(2)}, \dots, x^{(B)}\}.
# $$
# Only the samples collected after the burn-in period are used to estimate properties of the target distribution.
#
# ## Example walk
# ![image.png](data:image/png;base64,...)

# %%
# !pip install blackjax
# Out:
# Collecting blackjax
#   Downloading blackjax-1.5-py3-none-any.whl.metadata (6.6 kB)
# Collecting jax>=0.9.0 (from blackjax)
#   Downloading jax-0.9.2-py3-none-any.whl.metadata (13 kB)
# Collecting jaxlib>=0.9.0 (from blackjax)
#   Downloading jaxlib-0.9.2-cp312-cp312-manylinux_2_27_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.12/dist-packages (from blackjax) (2.0.2)
# Requirement already satisfied: optax>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from blackjax) (0.2.8)
# Requirement already satisfied: scipy>=1.13 in /usr/local/lib/python3.12/dist-packages (from blackjax) (1.16.3)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from blackjax) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from jax>=0.9.0->blackjax) (0.5.4)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from jax>=0.9.0->blackjax) (3.4.0)
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from optax>=0.2.3->blackjax) (1.4.0)
# Downloading blackjax-1.5-py3-none-any.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 28.2 MB/s eta 0:00:00
# Downloading jax-0.9.2-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 36.8 MB/s eta 0:00:00
# Downloading jaxlib-0.9.2-cp312-cp312-manylinux_2_27_x86_64.whl (83.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.3/83.3 MB 7.7 MB/s eta 0:00:00
# Installing collected packages: jaxlib, jax, blackjax
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.7.2
#     Uninstalling jaxlib-0.7.2:
#       Successfully uninstalled jaxlib-0.7.2
#   Attempting uninstall: jax
#     Found existing installation: jax 0.7.2
#     Uninstalling jax-0.7.2:
#       Successfully uninstalled jax-0.7.2
# Successfully installed blackjax-1.5 jax-0.9.2 jaxlib-0.9.2

# %%
# warm up
import matplotlib.pyplot as plt

import jax
import jax.numpy as jnp
import jax.random as rdm
import jax.scipy.stats as stats

import blackjax


seed = 10
rng_key = rdm.PRNGKey(seed)

# true values that generate our observations
rng_key, o_key = rdm.split(rng_key)
loc, scale = 10, 20
observed = loc + scale * rdm.normal(o_key, shape=(1_000,))

# we need to define the log function for blackjax to sample from

# set up our density function
def logdensity_fn(loc, log_scale, observed=observed):
  # log_scale is is to widen the Neal's funnel, because at the center there is hard to sample
    """Univariate Normal"""
    scale = jnp.exp(log_scale)
    logpdf = stats.norm.logpdf(observed, loc, scale)
    return jnp.sum(logpdf)


def logdensity(x):
  return logdensity_fn(**x)
# ** means if x a dictionary, ** unpack it to key n value pairs.
# A way to pass around a dinctionary and unpack it

# kernel params
inv_mass_matrix = jnp.array([0.5, 0.01])
num_integration_steps = 60
step_size = 1e-3

# set up our kernel
## Kernel: core object drives our sampling
## Leveraging the gradient so we need to provide step size
hmc = blackjax.hmc(logdensity, step_size, inv_mass_matrix, num_integration_steps)
nuts = blackjax.nuts(logdensity, step_size, inv_mass_matrix)

# sample from posterior
rng_key, sample_key = rdm.split(rng_key)

initial_position = {"loc": 1.0, "log_scale": 1.0}
initial_state = nuts.init(initial_position)
hmc_kernel = jax.jit(hmc.step)
nuts_kernel = jax.jit(nuts.step)


def inference_loop(rng_key, kernel, initial_state, num_samples):
    @jax.jit
    def one_step(state, rng_key):
        state, _ = kernel(rng_key, state)
        return state, state

    keys = jax.random.split(rng_key, num_samples)
    _, states = jax.lax.scan(one_step, initial_state, keys)

    # we carry the states (state 1 ,...state n) and we stack them
    # State means our samples.

    return states

states = inference_loop(sample_key, nuts_kernel, initial_state, 4_000)

mcmc_samples = states.position
mcmc_samples["scale"] = jnp.exp(mcmc_samples["log_scale"]).block_until_ready()

# visualize results
fig, (ax, ax1) = plt.subplots(ncols=2, figsize=(15, 6))
ax.plot(mcmc_samples["loc"])
ax.set_xlabel("Samples")
ax.set_ylabel("loc")

ax1.plot(mcmc_samples["scale"])
ax1.set_xlabel("Samples")
ax1.set_ylabel("scale");

# %% [markdown]
# Let's try sampling again, but this time drop/ignore samples from the burn-in phase.

# %%
burn_in = 1_000
rng_key, sample_key = rdm.split(rng_key)
states = inference_loop(sample_key, nuts_kernel, initial_state, 5_000)

mcmc_samples = states.position
mcmc_samples["scale"] = jnp.exp(mcmc_samples["log_scale"]).block_until_ready()

# visualize results
fig, (ax, ax1) = plt.subplots(ncols=2, figsize=(15, 6))
ax.plot(mcmc_samples["loc"][burn_in:])
ax.set_xlabel("Samples")
ax.set_ylabel("loc")

ax1.plot(mcmc_samples["scale"][burn_in:])
ax1.set_xlabel("Samples")
ax1.set_ylabel("scale");

# %%
locs = mcmc_samples["loc"][burn_in:]
scales = mcmc_samples["scale"][burn_in:]
print(f"median loc = {jnp.median(locs):.3f} | median scale = {jnp.median(scales):.3f}")
# Out:
# median loc = 10.777 | median scale = 20.013

# %% [markdown]
# ## Bayesian Logistic Regression, revisited
#
# Recall, ...

# %%
import matplotlib.pyplot as plt
import jax.numpy as jnp
import blackjax

from sklearn.datasets import make_biclusters


plt.rcParams["axes.spines.right"] = False
plt.rcParams["axes.spines.top"] = False
plt.rcParams["figure.figsize"] = (12, 8)

seed = 0
rng_key = jax.random.key(seed)

# generate data
num_points = 50
X, rows, cols = make_biclusters(
    (num_points, 2), 2, noise=1.5, random_state=314, minval=-3, maxval=3
)
y = rows[0] * 1.0  # y[i] = whether point i belongs to cluster 1

# visualize data/labels
colors = ["tab:red" if el else "tab:blue" for el in rows[0]]
plt.scatter(*X.T, edgecolors=colors, c="none")
plt.xlabel(r"$X_0$")
plt.ylabel(r"$X_1$");

# %%
# set up likelihoods
import jax.nn as nn

# Phi = [1, X_1, X_2]
Phi = jnp.c_[jnp.ones(num_points)[:, None], X]
N, M = Phi.shape

#print(f"Phi = {Phi}")
#print(f"Phi = {Phi.shape}")

def logdensity_fn(w, alpha=1.0):

  # joint funcetion : pror and posterior
    r"""The log-probability density function of the posterior distribution of the model.

      - `w`: the weights for our logistic regression model.
      - `alpha`: the prior precision for our weights under normality.
        (i.e. $w_j \sim \text{N}(0, 1 / alpha)$)
    """
    # Wrong answer
    ## scale = jnp.exp(1/alpha)
    ## logpdf = stats.norm.logpdf(w, scale)
    ## return jnp.sum(logpdf)

    # Correct answer
    eta = Phi @ w
    term1 = -jnp.sum(nn.softplus(-y * eta))
    term2 = jnp.sum((1-y)*eta)
# Term 1 and term 2 is for posterior log likelihood
# multiole observation, add them up

    term3 = jnp.sum((w ** 2) * alpha + jnp.log(alpha))
    return  term1 + term2 + term3


# sample initial weights, w
rng_key, init_key = jax.random.split(rng_key)
w0 = jax.random.multivariate_normal(init_key, 0.1 + jnp.zeros(M), jnp.eye(M))

rmh = blackjax.rmh(logdensity_fn, blackjax.mcmc.random_walk.normal(jnp.ones(M) * 0.05))
initial_state = rmh.init(w0)

# set up inference loop
def inference_loop(rng_key, kernel, initial_state, num_samples):
    @jax.jit
    def one_step(state, rng_key):
        state, _ = kernel(rng_key, state)
        return state, state

    keys = jax.random.split(rng_key, num_samples)
    _, states = jax.lax.scan(one_step, initial_state, keys)

    return states

# perform inference and sample
rng_key, sample_key = jax.random.split(rng_key)
states = inference_loop(sample_key, rmh.step, initial_state, 5_000)

# %%
burnin = 300

fig, ax = plt.subplots(1, 3, figsize=(12, 2))
for i, axi in enumerate(ax):
    axi.plot(states.position[:, i])
    axi.set_title(f"$w_{i}$")
    axi.axvline(x=burnin, c="tab:red")
plt.show()

# %%
# Create a meshgrid
xmin, ymin = X.min(axis=0) - 0.1
xmax, ymax = X.max(axis=0) + 0.1
step = 0.1
Xspace = jnp.mgrid[xmin:xmax:step, ymin:ymax:step]
_, nx, ny = Xspace.shape

burnin = 300
chains = states.position[burnin:, :]
nsamp, _ = chains.shape

# Compute the average probability to belong to the first cluster at each point on the meshgrid
Phispace = jnp.concatenate([jnp.ones((1, nx, ny)), Xspace])
Z_mcmc = nn.sigmoid(jnp.einsum("mij,sm->sij", Phispace, chains))
Z_mcmc = Z_mcmc.mean(axis=0)
plt.contourf(*Xspace, Z_mcmc)
plt.scatter(*X.T, c=colors)
plt.xlabel(r"$X_0$")
plt.ylabel(r"$X_1$");
